# %%
a = 10
b = 20

print("a is max") if a>b else print("b is max")
# Out:
# b is max

# %%
# Out:
# a is max

# %%
a = 8
z = ("odd", "even")[a%2 == 0]
print("Z = ", z)
# Out:
# Z =  even

# %%
a = 100
b = 20
z = {True: a, False: b}[a>b]
print("Z = ", z)
# Out:
# Z =  100

# %% [markdown]
# ## For Loop

# %%
a = 100
b = 20
z = (b,a) [a>b] 
print("Z = ", z)
# Out:
# Z =  100

# %%
# For Loop

for i in range(5):
    print("i = ", i)
# Out:
# i =  0
# i =  1
# i =  2
# i =  3
# i =  4

# %%
a = 100
b = 200
z = (b,a) [a>b] # z = (False, True)[a>b]
print("Z = ", z)
# Out:
# Z =  200

# %%
for i in range (2,5): # for i in range (initial_value, final_value)
    print("i = ", i)
# Out:
# i =  2
# i =  3
# i =  4

# %%
for i in range (2,5): # for i in range (initial_value, final_value)
    print("i = ", +i)
# Out:
# i =  2
# i =  3
# i =  4

# %%
for i in range(2, 10, 3): # for i in range (initial_value, final_value, gap_between_values)
    print("i = ", i)
# Out:
# i =  2
# i =  5
# i =  8

# %%
n = int(input("Enter a number: "))
f = 1
for i in range (1, n+1):
    f = f*i
print("Factorial Value: ", f)
# Out:
# Enter a number:  2
# Factorial Value:  2

# %% [markdown]
# ## write a programm to check the given number is prime or not

# %%
# write a programm to check the given number is prime or not

n = int(input("Enter a number: "))
for i in range (2, n//2):
    if (n%i == 0):
        flag = 1
        break
if flag == 0:
    print("n = ", n, " is Prime")
else:
    print("n = ", n, " isn't prime")
# Out:
# Enter a number:  4
# n =  4  isn't prime

# %%
n = int(input("Enter a number: "))
f = 1
while(n>1):
    f = f*n
    n = n-1
print("Factorial", f)
# Out:
# Enter a number:  5
# Factorial 120

# %%
n = int(input("Enter a number: "))
f = 1
while(n>1):
    f = f*n
    n -= 1
print("Factorial", f)
# Out:
# Enter a number:  4
# Factorial 24

# %% [markdown]
# ## Reverse

# %%
n = int(input("Enter a number: "))

n1 = n
f = 0
while n>0:
    r = n%10
    f = f*10+r
    n = n//10
print("Reverse: ", f)
# Out:
# Enter a number:  4556
# 6554

# %%
n = int(input("Enter a number: "))
y = 0
while(n>0):
    r = int(n%10)
    n = n//10
    y = y*10+r
print("Reverse: ", y)
# Out:
# Enter a number:  123
# Reverse:  321

# %% [markdown]
# ## Armstrony Number

# %%
n = int(input("Enter a no: "))
c = 0
x = n
s = 0
while(n>0):
    n = n//10
    c = c + 1
n = x
while(n>0):
    r = n%10
    n = n//10
    s = s + pow(r,c)
if x == s:
    print("Armstrony")
else:
    print("Non-Armstrony")

# %% [markdown]
# ## Palindrome

# %% [markdown]
# ## Palindrome

# %%
number = int(input("Enter a number: "))

original_number = number
reversed_number = 0

while number > 0:
    digit = number % 10
    reversed_number = reversed_number * 10 + digit
    number //= 10

# Check if the original number is the same as the reversed number
if original_number == reversed_number:
    print(f"{original_number} is a Palindrome number.")
else:
    print(f"{original_number} is not a Palindrome number.")
